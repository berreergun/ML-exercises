# %% [markdown]
# <a href="https://colab.research.google.com/github/berreergun/ML-exercises/blob/main/mlOreilly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
x = np.arange(-3, 3, 0.01)

plt.plot(x, norm.pdf(x))
plt.show()

# %%
import matplotlib.pyplot as plt
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
import pandas as pd

df = pd.read_csv("FuelEfficiency.csv")

gear_counts = df['# Gears'].value_counts()

gear_counts.plot(kind='bar')
# Out:
# <Axes: xlabel='# Gears'>

# %%
import seaborn as sns
sns.set()

# %%
gear_counts.plot(kind='Gears')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-622907b90e8e> in <cell line: 1>()
# ----> 1 gear_counts.plot(kind='Gears')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     962
#     963         if kind not in self._all_kinds:
# --> 964             raise ValueError(f"{kind} is not a valid plot kind")
#     965
#     966         # The original data structured can be transformed before passed to the
#
# ValueError: Gears is not a valid plot kind

# %%
sns.distplot(df['Gears'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gears'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-cfcc15fb09fd> in <cell line: 1>()
# ----> 1 sns.distplot(df['Gears'])
#
# ...

# %%
sns.distplot(df['CombMPG'])
# Out:
# <ipython-input-6-5ac86d31f115>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CombMPG'])
# <Axes: xlabel='CombMPG', ylabel='Density'>

# %%
sns.scatterplot(x="Eng Displ", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='Eng Displ', ylabel='CombMPG'>

# %%
sns.scatterplot(x="# Gears", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.lmplot(x="# Gears", y="CombMPG", data=df)

# %%
sns.jointplot(x="# Gears", y="CombMPG", data=df)

# %%
sns.boxplot(x="# Gears", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.swarmplot(x="# Gears", y="CombMPG", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 27.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 50.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return dot(de_mean(x), de_mean(y)) / (n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# 0.2708602431308115

# %%
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# -7.157747092991947

# %%
purchaseAmount = 50 - pageSpeeds * 7

scatter(pageSpeeds, purchaseAmount)

np.corrcoef (pageSpeeds, purchaseAmount)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
from numpy import random
random.seed(0)

totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20, 30, 40, 50, 60, 70])
    purchaseProbability = 0.36
    totals[ageDecade] += 1
    if (random.random() < purchaseProbability):
        totalPurchases += 1
        purchases[ageDecade] += 1

# %%
totals
# Out:
# {20: 16576, 30: 16619, 40: 16632, 50: 16805, 60: 16664, 70: 16704}

# %%
purchases
# Out:
# {20: 6047, 30: 5968, 40: 5983, 50: 5999, 60: 5983, 70: 6055}

# %%
totalPurchases
# Out:
# 36035

# %%
PEF = float(purchases[30]) / float(totals[30])
print('P(purchase | 30s): ' + str(PEF))
# Out:
# P(purchase | 30s): 0.3591070461519947

# %%
PF = float(totals[30]) / 100000.0
print("P(30's): " +  str(PF))
# Out:
# P(30's): 0.16619

# %%
PE = float(totalPurchases) / 100000.0
print("P(Purchase):" + str(PE))
# Out:
# P(Purchase):0.36035

# %%
# %matplotlib inline
from pylab import *
import numpy as np

np.random.seed(2)
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)


x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p4 = np.poly1d(np.polyfit(x, y, 5))

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 10, 100)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))

print(r2)
# Out:
# 0.8553884386186104

# %%
import pandas as pd
df = pd.read_excel('http://cdn.sundog-soft.com/Udemy/DataScience/cars.xls')

# %%
# %matplotlib inline
import numpy as np
df1=df[['Mileage','Price']]
bins =  np.arange(0,50000,10000)
groups = df1.groupby(pd.cut(df1['Mileage'],bins)).mean()
print(groups.head())
groups['Price'].plot.line()
# Out:
#                      Mileage         Price
# Mileage
# (0, 10000]       5588.629630  24096.714451
# (10000, 20000]  15898.496183  21955.979607
# (20000, 30000]  24114.407104  20278.606252
# (30000, 40000]  33610.338710  19463.670267
# <ipython-input-3-85c28d137f2c>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = df1.groupby(pd.cut(df1['Mileage'],bins)).mean()
# <Axes: xlabel='Mileage'>

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['Mileage', 'Cylinder', 'Doors']]
x = df[['Mileage', 'Cylinder', 'Doors']]
y = df['Price']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y)
x_train2, x_test2, y_train2, y_test2 = train_test_split(X, y)

x_train[['Mileage', 'Cylinder', 'Doors']] = scale.fit_transform(x_train[['Mileage', 'Cylinder', 'Doors']].values)

# Add a constant column to our model so we can have a Y-intercept
x_train = sm.add_constant(x_train)
x_train2 = sm.add_constant(x_train2)
print (x_train2)
print (y_test)

est = sm.OLS(y_train, x_train).fit()
est2 = sm.OLS(y_train2, x_train2).fit()

print(est.summary())
print(est2.summary())
# Out:
#      const  Mileage  Cylinder  Doors
# 616    1.0    21461         4      4
# 665    1.0    21160         4      4
# 309    1.0    32844         4      2
# 260    1.0     8427         4      4
# 169    1.0    29680         4      4
# ..     ...      ...       ...    ...
# 661    1.0    10014         4      4
# 494    1.0    20510         6      4
# 232    1.0    17741         4      2
# 294    1.0    22382         4      2
# 127    1.0    23124         8      4
#
# [603 rows x 4 columns]
# 51     21956.342663
# 617    15086.899592
# 778    12162.140047
# 482    23578.164861
# 555    16569.141240
#            ...
# 280    15553.208714
# 208     9789.037676
# 150    70755.466717
# 504    22004.930438
# 734    29197.791300
# Name: Price, Length: 201, dtype: float64
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.314
# ...

# %%
import matplotlib.pyplot as plt
xp = np.linspace(0, 10000, 100)
print (y_test)

scaled =  scale.transform(x_test[['Mileage', 'Cylinder', 'Doors']].values)
scaled = np.insert(scaled[0], 0, 1) #Need to add that constant column in again.
print (est2.predict(np.insert(x_test2)))
print (est.predict(x_test))

#plt.plot(xp, y_test[1], c='r')
plt.plot(xp, est.predict(x_test), c='g')
plt.plot(xp, est2.predict(x_test2), c='b')
plt.show()
# Out:
# 51     21956.342663
# 617    15086.899592
# 778    12162.140047
# 482    23578.164861
# 555    16569.141240
#            ...
# 280    15553.208714
# 208     9789.037676
# 150    70755.466717
# 504    22004.930438
# 734    29197.791300
# Name: Price, Length: 201, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-03e4179fb903> in <cell line: 7>()
#       5 scaled =  scale.transform(x_test[['Mileage', 'Cylinder', 'Doors']].values)
#       6 scaled = np.insert(scaled[0], 0, 1) #Need to add that constant column in again.
# ----> 7 print (est2.predict(np.insert(x_test2)))
#       8 print (est.predict(x_test))
#       9
#
# TypeError: insert() missing 2 required positional arguments: 'obj' and 'values'

# %% [markdown]
# # Supervised

# %%
# %matplotlib inline
import numpy as np
from pylab import *

np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


scatter(pageSpeeds, purchaseAmount)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(pageSpeeds, purchaseAmount)

# %%
scatter(x_train, y_train)

# %%
scatter(x_test, y_test)

# %%
x = np.array(x_train)
y = np.array(y_train)

p4 = np.poly1d(np.polyfit(x, y, 5))

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
testx = np.array(x_test)
testy = np.array(y_test)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.scatter(x_test, p4(x_test), c='g')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(y_test), p4(np.array(x_test)))
print(r2)
r2 = r2_score(np.array(y_train), p4(np.array(x_train)))

print(r2)
# Out:
# 0.3421480913995675
# 0.5724179926945254

# %% [markdown]
# # **KMEAN**

# %%
from numpy import random, array

#Create fake income/age clusters for N people in k clusters
def createClusteredData(N, k):
    random.seed(10)
    pointsPerCluster = float(N)/k
    X = []
    for i in range (k):
        incomeCentroid = random.uniform(20000.0, 200000.0)
        ageCentroid = random.uniform(20.0, 70.0)
        for j in range(int(pointsPerCluster)):
            X.append([random.normal(incomeCentroid, 10000.0), random.normal(ageCentroid, 2.0)])
    X = array(X)
    return X

# %%
from numpy import random, array
incomeCentroid = random.uniform(20000.0, 200000.0)
nomal = random.normal(incomeCentroid, 10000.0)
incomeCentroid
nomal
# Out:
# 170288.32296922678
